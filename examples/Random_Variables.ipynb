# %%
# %matplotlib inline

import tdpy
import numpy as np

# Sampling from a bounded power-law probability distribution with slope
## number of samples
n_samples = 10000

## minimum of the parameter
minimum = 0.1

## maximum of the parameter
maximum = 10.

## negative slope of the parameter
slope = 2.

## label for the plotted parameter and its unit
labels = ['$\log_{10} x$', '']

# sample from the power law
x = tdpy.samp_powr(n_samples, minimum, maximum, slope)

# plot the samples
tdpy.plot_grid(np.log10(x), labels)
